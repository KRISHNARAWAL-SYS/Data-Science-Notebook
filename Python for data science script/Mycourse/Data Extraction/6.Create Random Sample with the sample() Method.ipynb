# %%
import pandas as pd

# %%
# read csv file
df = pd.read_csv(r"C:\Users\krishna rawal\OneDrive\Desktop\players_20.csv")
# set index
df.set_index('short_name', inplace = True)  
# Select column
df= df[['long_name','age','dob','height_cm','weight_kg','nationality','club']]

# %%
# show data frame
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# Neymar Jr                175         68      Brazil
# J. Oblak                 188         87    Slovenia
# E. Hazard                175         74     Belgium
# ...                      ...        ...         ...
# Shao Shuai               186         79    China PR
# Xiao Mingjie             177         66    China PR
# Zhang Wei                186         75    China PR
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# Neymar Jr                    Paris Saint-Germain
# J. Oblak                         Atlético Madrid
# E. Hazard                            Real Madrid
# ...                                          ...
# Shao Shuai                      Beijing Renhe FC
# Xiao Mingjie                    Shanghai SIPG FC
# Zhang Wei                 Hebei China Fortune FC
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %% [markdown]
# # 1 Sample()

# %%
# extract 10 random elements from the "nationality" column
df['nationality'].sample(10 ,  random_state=99)
# Out:
# short_name
# R. Alvarado               Mexico
# Qiao Wei                China PR
# E. Paredes                 Chile
# K. Stoyanov             Bulgaria
# M. Chudý                Slovakia
# D. Sundaram                India
# R. Gagliardini             Italy
# G. Debeljuh              Croatia
# Kim Seung Yong    Korea Republic
# M. Hansen                Denmark
# Name: nationality, dtype: object

# %%
#extract a random 20% sample of the dataframe
df.sample(frac=0.2 , random_state=12)
# Out:
#                                long_name  age         dob  height_cm  \
# short_name
# Y. Thoelen               Yannick Thoelen   28  1990-07-18        188
# M. Nadé                     Mickaël Nadé   20  1999-03-04        188
# V. García   Víctor Hugo García Hernández   25  1994-06-11        178
# M. Gyamfi                 Maxwell Gyamfi   19  2000-01-18        185
# W. Cyprien                 Wylan Cyprien   24  1995-01-28        180
# ...                                  ...  ...         ...        ...
# H. Kadish                  Hassan Kadish   26  1992-09-26        179
# A. Chapman                 Aaron Chapman   29  1990-05-29        203
# I. Ezekiel                  Imoh Ezekiel   25  1993-10-24        178
# H. Sakai                           酒井 宏樹   29  1990-04-12        183
# C. Keșerü          Claudiu Andrei Keșerü   32  1986-12-02        178
#
#             weight_kg   nationality                    club
# short_name
# Y. Thoelen         89       Belgium             KV Mechelen
# M. Nadé            80        France        AS Saint-Étienne
# V. García          71     Venezuela       Vitória Guimarães
# M. Gyamfi          75       Germany         VfL Bochum 1848
# W. Cyprien         75        France                OGC Nice
# ...               ...           ...                     ...
# H. Kadish          73  Saudi Arabia                Al Hilal
# A. Chapman         92       England     Peterborough United
# I. Ezekiel         70       Nigeria             KV Kortrijk
# H. Sakai           70         Japan  Olympique de Marseille
# C. Keșerü          71       Romania                 Romania
#
# [3656 rows x 7 columns]

# %%
# unsample: increase the sampling rate -> frac >1 (Note : replace parameter has to be True for frac parameter > 1 )
df.sample(frac = 2 , replace=True )
# Out:
#                                      long_name  age         dob  height_cm  \
# short_name
# K. Kennedy                      Kieran Kennedy   25  1993-09-23        183
# V. Rongier                    Valentin Rongier   24  1994-12-07        172
# A. Di María    Ángel Fabián Di María Hernández   31  1988-02-14        180
# A. Al Riou           Abdulrahman Khalid Al Rio   25  1994-05-15        189
# M. Senesi                        Marcos Senesi   22  1997-05-10        183
# ...                                        ...  ...         ...        ...
# C. Larin                            Cyle Larin   24  1995-04-17        187
# O. Abildgaard                Oliver Abildgaard   23  1996-06-10        192
# A. Attiah                   Abdulquddus Attiah   22  1997-03-01        190
# S. Glarner                      Stefan Glarner   31  1987-11-21        177
# S. Knežević                    Stefan Knežević   22  1996-10-30        187
#
#                weight_kg   nationality                    club
# short_name
# K. Kennedy            70       England               Port Vale
# V. Rongier            70        France               FC Nantes
# A. Di María           69     Argentina     Paris Saint-Germain
# A. Al Riou            70  Saudi Arabia                Al Wehda
# M. Senesi             80     Argentina  San Lorenzo de Almagro
# ...                  ...           ...                     ...
# C. Larin              92        Canada        SV Zulte-Waregem
# O. Abildgaard         86       Denmark              Aalborg BK
# A. Attiah             77  Saudi Arabia                Al Wehda
# S. Glarner            74   Switzerland                 FC Thun
# S. Knežević           81   Switzerland               FC Luzern
#
# [36556 rows x 7 columns]
