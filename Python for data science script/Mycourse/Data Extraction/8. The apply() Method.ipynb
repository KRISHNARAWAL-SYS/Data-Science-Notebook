# %%
import pandas as pd

# %%
# read csv file
df = pd.read_csv(r"C:\Users\krishna rawal\OneDrive\Desktop\players_20.csv")
# set index
df.set_index('short_name', inplace = True)  
# Select column
df= df[['long_name','age','dob','height_cm','weight_kg','nationality','club']]

# %%
# show dataframe 
df.head(10)

# %% [markdown]
# ## 1 .apply()

# %%
# use numpy function and apply it to series
import numpy as np
df['age'].apply(np.sqrt)

# %%
# create ur own functn and apply it to a dataframe

def calculate_bmi(row):
    return row['weight_kg'] / (row['height_cm']/100)**2

# %%
df.apply(calculate_bmi , axis=1)    # axis indicates how we want to apply this function for multiple columns we use Axis=1
