# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv(r"C:\Users\krishna rawal\dataset.csv")
df_exams.head()
# Out:
#                                    hospital_name  gender   color  \
# 0                     WAGONER HOSPITAL AUTHORITY  Female  Maroon
# 1           ATHOL MEMORIAL HOSPITAL INCORPORATED  Female  Orange
# 2  MCLEOD REGIONAL MEDICAL CENTER OF PEE DEE INC    Male   Khaki
# 3                        SUTTER VALLEY HOSPITALS    Male  Maroon
# 4                 NORTH SUNFLOWER MEDICAL CENTER    Male    Pink
#
#                 job_title          ssn   birthdate            city    country  \
# 0           Social Worker  414-96-9723   9/23/1980  Fraile Pintado  Argentina
# 1           Social Worker  158-68-8337   8/31/1954         Taxisco  Guatemala
# 2        Quality Engineer  656-97-2511   3/16/1973           Sakai      Japan
# 3         Web Developer I  598-01-7806   5/14/1974         Кондово  Macedonia
# 4  Senior Sales Associate  776-58-1786  12/30/1962            Bāfq       Iran
#
#    phone_number                       email
# 0  644-374-7372       gchansonnau0@live.com
# ...

# %% [markdown]
# # Selectingone column

# %% [markdown]
# ### 1.1 Syntax 1

# %%
# slecting a column with [] (preferred way to select a column)
df_exams['gender']
# Out:
# 0      Female
# 1      Female
# 2        Male
# 3        Male
# 4        Male
#         ...
# 995    Female
# 996    Female
# 997      Male
# 998    Female
# 999      Male
# Name: gender, Length: 1000, dtype: str

# %%
# checkout the data type of a column
type(df_exams['gender'])
# Out:
# pandas.Series

# %%
# series : attributes and methods
df_exams['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# 2.
df_exams['gender'].head(5)
# Out:
# 0    Female
# 1    Female
# 2      Male
# 3      Male
# 4      Male
# Name: gender, dtype: str

# %% [markdown]
# ### 1.2 Syntax 2

# %%
# select a column with .
df_exams.gender
# Out:
# 0      Female
# 1      Female
# 2        Male
# 3        Male
# 4        Male
#         ...
# 995    Female
# 996    Female
# 997      Male
# 998    Female
# 999      Male
# Name: gender, Length: 1000, dtype: str

# %%
# select a column with . (pitfalls)
df_exams.phone number
# Out:
#   Cell In[11], line 2
#     df_exams.phone number
#                    ^
# SyntaxError: invalid syntax

# %%
# select a column with . (pitfalls)
df_exams.phone_number
# Out:
# 0      644-374-7372
# 1      487-683-5255
# 2      255-989-3989
# 3      650-792-4085
# 4      110-479-5503
#            ...
# 995    871-485-7072
# 996    824-715-0847
# 997    358-151-6573
# 998    466-151-5908
# 999    920-360-2577
# Name: phone_number, Length: 1000, dtype: str

# %%
df_exams['job_title']
# Out:
# 0                     Social Worker
# 1                     Social Worker
# 2                  Quality Engineer
# 3                   Web Developer I
# 4            Senior Sales Associate
#                    ...
# 995      Database Administrator III
# 996             Executive Secretary
# 997             Geological Engineer
# 998             Electrical Engineer
# 999    Human Resources Assistant II
# Name: job_title, Length: 1000, dtype: str
