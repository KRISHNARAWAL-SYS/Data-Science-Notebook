# %% [markdown]
# # Function

# %%
def function(<parameters>):
    <code>
    return <data>

# %%
def SUM(a , b):
    sum = a+b
    return sum

# %%
SUM(9,8)
# Out:
# 17

# %% [markdown]
# ### Built-in Functions

# %%
countries = ['united States','India','China','Brazil']

# %%
#1
len(countries)
# Out:
# 4

# %%
#2
max([10 , 454, 34, 2, 2349])
# Out:
# 2349

# %%
#3
min([10 , 454, 34, 2, 2349])
# Out:
# 2

# %%
#4
type(countries)
# Out:
# list

# %%
#5
range(1,10,
