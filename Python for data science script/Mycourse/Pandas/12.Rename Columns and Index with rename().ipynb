# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv(r"C:\Users\krishna rawal\dataset.csv")
df_exams.head()
# Out:
#                                    hospital_name  gender   color  \
# 0                     WAGONER HOSPITAL AUTHORITY  Female  Maroon
# 1           ATHOL MEMORIAL HOSPITAL INCORPORATED  Female  Orange
# 2  MCLEOD REGIONAL MEDICAL CENTER OF PEE DEE INC    Male   Khaki
# 3                        SUTTER VALLEY HOSPITALS    Male  Maroon
# 4                 NORTH SUNFLOWER MEDICAL CENTER    Male    Pink
#
#                 job_title          ssn   birthdate            city    country  \
# 0           Social Worker  414-96-9723   9/23/1980  Fraile Pintado  Argentina
# 1           Social Worker  158-68-8337   8/31/1954         Taxisco  Guatemala
# 2        Quality Engineer  656-97-2511   3/16/1973           Sakai      Japan
# 3         Web Developer I  598-01-7806   5/14/1974         Кондово  Macedonia
# 4  Senior Sales Associate  776-58-1786  12/30/1962            Bāfq       Iran
#
#    phone_number                       email
# 0  644-374-7372       gchansonnau0@live.com
# ...

# %% [markdown]
# # 1 Rename Column

# %%
# rename column and overwrite values of the dataframe
df_exams=df_exams.rename(columns={'gender':'Gender'})

# %%
# updation of dataframe
df_exams
# Out:
#                                      hospital_name  Gender   color  \
# 0                       WAGONER HOSPITAL AUTHORITY  Female  Maroon
# 1             ATHOL MEMORIAL HOSPITAL INCORPORATED  Female  Orange
# 2    MCLEOD REGIONAL MEDICAL CENTER OF PEE DEE INC    Male   Khaki
# 3                          SUTTER VALLEY HOSPITALS    Male  Maroon
# 4                   NORTH SUNFLOWER MEDICAL CENTER    Male    Pink
# ..                                             ...     ...     ...
# 995            PROMISE HOSPITAL OF ASCENSION, INC.  Female    Teal
# 996                         THE CAMBRIDGE HOSPITAL  Female  Indigo
# 997                   EAST ORANGE GENERAL HOSPITAL    Male  Orange
# 998                        SALEM MEMORIAL HOSPITAL  Female  Maroon
# 999                  MARY IMOGENE BASSETT HOSPITAL    Male     Red
#
#                         job_title          ssn   birthdate             city  \
# 0                   Social Worker  414-96-9723   9/23/1980   Fraile Pintado
# ...

# %%
# rename multiple columns and update the dataframe with inplace argument
df_exams.rename(columns={'phone_number':'Mobile_number',
                        'city':'town',
                        'color':'Rang'})
# Out:
#                                      hospital_name  Gender    Rang  \
# 0                       WAGONER HOSPITAL AUTHORITY  Female  Maroon
# 1             ATHOL MEMORIAL HOSPITAL INCORPORATED  Female  Orange
# 2    MCLEOD REGIONAL MEDICAL CENTER OF PEE DEE INC    Male   Khaki
# 3                          SUTTER VALLEY HOSPITALS    Male  Maroon
# 4                   NORTH SUNFLOWER MEDICAL CENTER    Male    Pink
# ..                                             ...     ...     ...
# 995            PROMISE HOSPITAL OF ASCENSION, INC.  Female    Teal
# 996                         THE CAMBRIDGE HOSPITAL  Female  Indigo
# 997                   EAST ORANGE GENERAL HOSPITAL    Male  Orange
# 998                        SALEM MEMORIAL HOSPITAL  Female  Maroon
# 999                  MARY IMOGENE BASSETT HOSPITAL    Male     Red
#
#                         job_title          ssn   birthdate             town  \
# 0                   Social Worker  414-96-9723   9/23/1980   Fraile Pintado
# ...

# %%
# Show dataframe
df_exams # NOT UPDATED AS WE DIDN'T ASSIGN THE DATAFRAME NAME TO THE NEW MODIFIED DATA
# Out:
#                                      hospital_name  Gender   color  \
# 0                       WAGONER HOSPITAL AUTHORITY  Female  Maroon
# 1             ATHOL MEMORIAL HOSPITAL INCORPORATED  Female  Orange
# 2    MCLEOD REGIONAL MEDICAL CENTER OF PEE DEE INC    Male   Khaki
# 3                          SUTTER VALLEY HOSPITALS    Male  Maroon
# 4                   NORTH SUNFLOWER MEDICAL CENTER    Male    Pink
# ..                                             ...     ...     ...
# 995            PROMISE HOSPITAL OF ASCENSION, INC.  Female    Teal
# 996                         THE CAMBRIDGE HOSPITAL  Female  Indigo
# 997                   EAST ORANGE GENERAL HOSPITAL    Male  Orange
# 998                        SALEM MEMORIAL HOSPITAL  Female  Maroon
# 999                  MARY IMOGENE BASSETT HOSPITAL    Male     Red
#
#                         job_title          ssn   birthdate             city  \
# 0                   Social Worker  414-96-9723   9/23/1980   Fraile Pintado
# ...

# %% [markdown]
# # 2. Rename Index

# %%
# rename index 0 ,1 and 2 and update the dataframe
df_exams.rename(index={0:'A',1:'B',2:'C'},inplace = True)
df_exams
# Out:
#                                      hospital_name  Gender   color  \
# A                       WAGONER HOSPITAL AUTHORITY  Female  Maroon
# B             ATHOL MEMORIAL HOSPITAL INCORPORATED  Female  Orange
# C    MCLEOD REGIONAL MEDICAL CENTER OF PEE DEE INC    Male   Khaki
# 3                          SUTTER VALLEY HOSPITALS    Male  Maroon
# 4                   NORTH SUNFLOWER MEDICAL CENTER    Male    Pink
# ..                                             ...     ...     ...
# 995            PROMISE HOSPITAL OF ASCENSION, INC.  Female    Teal
# 996                         THE CAMBRIDGE HOSPITAL  Female  Indigo
# 997                   EAST ORANGE GENERAL HOSPITAL    Male  Orange
# 998                        SALEM MEMORIAL HOSPITAL  Female  Maroon
# 999                  MARY IMOGENE BASSETT HOSPITAL    Male     Red
#
#                         job_title          ssn   birthdate             city  \
# A                   Social Worker  414-96-9723   9/23/1980   Fraile Pintado
# ...

# %%
# Show first three Row
df_exams.head(3)
# Out:
#                                    hospital_name  Gender   color  \
# A                     WAGONER HOSPITAL AUTHORITY  Female  Maroon
# B           ATHOL MEMORIAL HOSPITAL INCORPORATED  Female  Orange
# C  MCLEOD REGIONAL MEDICAL CENTER OF PEE DEE INC    Male   Khaki
#
#           job_title          ssn  birthdate            city    country  \
# A     Social Worker  414-96-9723  9/23/1980  Fraile Pintado  Argentina
# B     Social Worker  158-68-8337  8/31/1954         Taxisco  Guatemala
# C  Quality Engineer  656-97-2511  3/16/1973           Sakai      Japan
#
#    phone_number                   email
# A  644-374-7372   gchansonnau0@live.com
# B  487-683-5255  cwinckworth1@about.com
# C  255-989-3989    hsollars2@google.com
