# %% [markdown]
# # HELLO WORLD

# %%
"hELLO wORLD"
# Out:
# 'hELLO wORLD'

# %%
#pRINTING mY NAME
print("kRISHNA")
# Out:
# kRISHNA

# %% [markdown]
# # Data Types

# %%
type(2.5)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type("krishna Rawl")
# Out:
# str

# %%
"krishna Rawl".upper()
#lower() can be used for small letter
# Out:
# 'KRISHNA RAWL'

# %%
"krishna rawl".title()
# Out:
# 'Krishna Rawl'

# %%
"krishna rawl".count('r')
# Out:
# 2

# %%
"krishna Rawl".replace('a','v')
# Out:
# 'krishnv Rvwl'
