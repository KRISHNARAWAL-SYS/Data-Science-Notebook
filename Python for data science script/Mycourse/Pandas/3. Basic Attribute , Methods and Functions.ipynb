# %%
import pandas as pd

# %%
# reading the csv file
df_exams = pd.read_csv(r"C:\Users\krishna rawal\dataset.csv")

# %%
# showing the dataframe
df_exams
# Out:
#                                      hospital_name  gender   color  \
# 0                       WAGONER HOSPITAL AUTHORITY  Female  Maroon
# 1             ATHOL MEMORIAL HOSPITAL INCORPORATED  Female  Orange
# 2    MCLEOD REGIONAL MEDICAL CENTER OF PEE DEE INC    Male   Khaki
# 3                          SUTTER VALLEY HOSPITALS    Male  Maroon
# 4                   NORTH SUNFLOWER MEDICAL CENTER    Male    Pink
# ..                                             ...     ...     ...
# 995            PROMISE HOSPITAL OF ASCENSION, INC.  Female    Teal
# 996                         THE CAMBRIDGE HOSPITAL  Female  Indigo
# 997                   EAST ORANGE GENERAL HOSPITAL    Male  Orange
# 998                        SALEM MEMORIAL HOSPITAL  Female  Maroon
# 999                  MARY IMOGENE BASSETT HOSPITAL    Male     Red
#
#                         job_title          ssn   birthdate             city  \
# 0                   Social Worker  414-96-9723   9/23/1980   Fraile Pintado
# ...

# %% [markdown]
# ## Attributes

# %%
# getting access to shape attribute
df_exams.shape
# Out:
# (1000, 10)

# %%
# getting access to the index attribute
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
# getting access to the column attribute
df_exams.columns
# Out:
# Index(['hospital_name', 'gender', 'color', 'job_title', 'ssn', 'birthdate',
#        'city', 'country', 'phone_number', 'email'],
#       dtype='str')

# %%
# data types of each column
df_exams.dtypes
# Out:
# hospital_name    str
# gender           str
# color            str
# job_title        str
# ssn              str
# birthdate        str
# city             str
# country          str
# phone_number     str
# email            str
# dtype: object

# %% [markdown]
# ## Methods

# %%
# Showing the first 5 columns
df_exams.head()
# Out:
#                                    hospital_name  gender   color  \
# 0                     WAGONER HOSPITAL AUTHORITY  Female  Maroon
# 1           ATHOL MEMORIAL HOSPITAL INCORPORATED  Female  Orange
# 2  MCLEOD REGIONAL MEDICAL CENTER OF PEE DEE INC    Male   Khaki
# 3                        SUTTER VALLEY HOSPITALS    Male  Maroon
# 4                 NORTH SUNFLOWER MEDICAL CENTER    Male    Pink
#
#                 job_title          ssn   birthdate            city    country  \
# 0           Social Worker  414-96-9723   9/23/1980  Fraile Pintado  Argentina
# 1           Social Worker  158-68-8337   8/31/1954         Taxisco  Guatemala
# 2        Quality Engineer  656-97-2511   3/16/1973           Sakai      Japan
# 3         Web Developer I  598-01-7806   5/14/1974         Кондово  Macedonia
# 4  Senior Sales Associate  776-58-1786  12/30/1962            Bāfq       Iran
#
#    phone_number                       email
# 0  644-374-7372       gchansonnau0@live.com
# ...

# %%
# showing the info of the dataframe
df_exams.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   hospital_name  1000 non-null   str
#  1   gender         1000 non-null   str
#  2   color          1000 non-null   str
#  3   job_title      1000 non-null   str
#  4   ssn            1000 non-null   str
#  5   birthdate      1000 non-null   str
#  6   city           1000 non-null   str
#  7   country        1000 non-null   str
#  8   phone_number   1000 non-null   str
#  9   email          1000 non-null   str
# dtypes: str(10)
# memory usage: 78.3 KB

# %%
# describing basic statistics of the dataframe
df_exams.describe()
# Out:
#                     hospital_name gender color                   job_title  \
# count                        1000   1000  1000                        1000
# unique                        898      8    19                         179
# top     MONTEFIORE MEDICAL CENTER   Male  Mauv  Desktop Support Technician
# freq                            5    483    64                          19
#
#                 ssn  birthdate        city country  phone_number  \
# count          1000       1000        1000    1000          1000
# unique         1000        975         974     130          1000
# top     414-96-9723  8/31/1954  San Isidro   China  644-374-7372
# freq              1          2           4     168             1
#
#                         email
# count                    1000
# unique                   1000
# top     gchansonnau0@live.com
# freq                        1

# %% [markdown]
# ## Functions

# %%
# Obtaining the length of the dataframe (number of columns)
len(df_exams)
# Out:
# 1000

# %%
# obtaining the highest index of the dataframe
max(df_exams.phone_number)
# Out:
# '999-564-5590'

# %%
# obtaining the lowest index of the dataframe
min(df_exams.phone_number)
# Out:
# '101-289-4410'

# %%
# obtaining the data type
type(df_exams)
# Out:
# pandas.DataFrame

# %%
# rounding the values of the dataset
round(df_exams , 2) # 2 --> round to 2 decimal point
# Out:
#                                      hospital_name  gender   color  \
# 0                       WAGONER HOSPITAL AUTHORITY  Female  Maroon
# 1             ATHOL MEMORIAL HOSPITAL INCORPORATED  Female  Orange
# 2    MCLEOD REGIONAL MEDICAL CENTER OF PEE DEE INC    Male   Khaki
# 3                          SUTTER VALLEY HOSPITALS    Male  Maroon
# 4                   NORTH SUNFLOWER MEDICAL CENTER    Male    Pink
# ..                                             ...     ...     ...
# 995            PROMISE HOSPITAL OF ASCENSION, INC.  Female    Teal
# 996                         THE CAMBRIDGE HOSPITAL  Female  Indigo
# 997                   EAST ORANGE GENERAL HOSPITAL    Male  Orange
# 998                        SALEM MEMORIAL HOSPITAL  Female  Maroon
# 999                  MARY IMOGENE BASSETT HOSPITAL    Male     Red
#
#                         job_title          ssn   birthdate             city  \
# 0                   Social Worker  414-96-9723   9/23/1980   Fraile Pintado
# ...
