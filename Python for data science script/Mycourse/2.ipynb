# %% [markdown]
# # HELLO WORLD

# %%
"hELLO wORLD"
# Out:
# 'hELLO wORLD'

# %%
#pRINTING mY NAME
print("kRISHNA")
# Out:
# kRISHNA

# %% [markdown]
# # Data Types

# %%
type(2.5)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type("krishna Rawl")
# Out:
# str

# %%
"krishna Rawl".upper()
#lower() can be used for small letter
# Out:
# 'KRISHNA RAWL'

# %%
"krishna rawl".title()
# Out:
# 'Krishna Rawl'

# %%
"krishna rawl".count('r')
# Out:
# 2

# %%
"krishna Rawl".replace('a','v')
# Out:
# 'krishnv Rvwl'

# %% [markdown]
# # Variables

# %%
message_1 = "i am learning Ds "

# %%
message_1
# Out:
# 'i am learning Ds'

# %%
  message_2 = "and is great career goal"

# %%
message_2
# Out:
# 'and is great career goal'

# %%
# String concatenation
msg = message_1 + ' ' +  message_2

# %%
msg
# Out:
# 'i am learning Ds and is great career goal'

# %%
# f string
f' Heloo kinni '
# Advantage - it can have variable inside a string
# Out:
# ' Heloo kinni '

# %%
f'{msg}'
# Out:
# 'i am learning Ds and is great career goal'

# %%
f'{msg} [joining message 1] --> {message_1}'
# Out:
# 'i am learning Ds and is great career goal [joining message 1] --> i am learning Ds'

# %% [markdown]
# # List

# %%
countries = ['india' , 'USA' , 'Japan' , 'poland']

# %%
countries
# Out:
# ['india', 'USA', 'Japan', 'poland']

# %%
# Indexing
print(countries[2])
print(countries[1])
print(countries[0])
# Out:
# Japan
# USA
# india

# %%
countries[-1]
# Out:
# 'poland'

# %%
#slicing
list_name[start:stop]

# %%
print(countries[1:3])
print(countries[1:])
print(countries[:2])
print(countries[0:1])
# Out:
# ['USA', 'Japan']
# ['USA', 'Japan', 'poland']
# ['india', 'USA']
# ['india']

# %% [markdown]
# ### Adding elements to list

# %%
#Append
countries.append(' canada ')

# %%
countries
# Out:
# ['india', 'USA', 'Japan', 'poland', ' canada ']

# %%
#Insert
countries.insert(1 , 'Egypt')
print(countries)
# Out:
# ['india', 'Egypt', 'Egypt', 'USA', 'Japan', 'poland', ' canada ']

# %%
countries_2 = ['Russia', 'France', 'Germany']

# %%
countries + countries_2
# Out:
# ['india',
#  'Egypt',
#  'Egypt',
#  'USA',
#  'Japan',
#  'poland',
#  ' canada ',
#  'Russia',
#  'France',
#  'Germany']

# %%
Nested_list = [countries , countries_2]
print(Nested_list)
# Out:
# [['india', 'Egypt', 'Egypt', 'USA', 'Japan', 'poland', ' canada '], ['Russia', 'France', 'Germany']]

# %% [markdown]
# ### Removing an ELement

# %%
States = ['rajhastha','UP','goa','Assam']

# %%
#Remove
States.remove('Assam')
print(States)
# Out:
# ['rajhastha', 'UP', 'goa']

# %%
#Pop
States.pop(-3)
print(States)
# Out:
# ['UP', 'goa']

# %%
# del  function
del States[0]    # (x2)
print(States)
# Out:
# []

# %% [markdown]
# ### Sorting a list

# %%
numbers = [2 , 3 ,10 , 1, 2, 34, 7, 23, 8, 43]
numbers.sort()

print(numbers)
# Out:
# [1, 2, 2, 3, 7, 8, 10, 23, 34, 43]

# %%
numbers.sort(reverse=True)
print(numbers)
# Out:
# [43, 34, 23, 10, 8, 7, 3, 2, 2, 1]

# %% [markdown]
# ### Update an ELement

# %%
numbers[0] = 1000
numbers
# Out:
# [1000, 34, 23, 10, 8, 7, 3, 2, 2, 1]

# %% [markdown]
# ### Copying alist

# %%
States = ['rajhasthan ', 'Goa ','maharashtra','haryana','kashmir']
new_list = States[:]  #Slicing full list

# %%
new_list
# Out:
# ['rajhasthan ', 'Goa ', 'maharashtra', 'haryana', 'kashmir']

# %%
new_list2 = States.copy()

# %%
new_list2
# Out:
# ['rajhasthan ', 'Goa ', 'maharashtra', 'haryana', 'kashmir']

# %% [markdown]
# ### Dictionary

# %%
my_dict = {'key1':'value1' , 'key2':'value2'}

# %%
my_data = {'Name':'KRishnaRawal' , 'Age' :'20'}

# %%
my_data
# Out:
# {'Name': 'KRishnaRawal', 'Age': '20'}

# %%
my_data.keys()
# Out:
# dict_keys(['Name', 'Age'])

# %%
my_data.values()
# Out:
# dict_values(['KRishnaRawal', '20'])

# %%
my_data.items()
# Out:
# dict_items([('Name', 'KRishnaRawal'), ('Age', '20')])

# %%
#Adding new element
my_data['height'] = 1.7
my_data
# Out:
# {'Name': 'KRishnaRawal', 'Age': '20', 'height': 1.7}

# %%
### Updation
my_data.update({'height':1.9})
my_data
# Out:
# {'Name': 'KRishnaRawal', 'Age': '20', 'height': 1.9}

# %% [markdown]
# #### Copy a Dictionary

# %%
new_data = my_data.copy()

# %%
new_data
# Out:
# {'Name': 'KRishnaRawal', 'Age': '20', 'height': 2.0}

# %% [markdown]
# #### Remove Element

# %%
my_data.pop('Age')
# Out:
# '20'

# %%
my_data
# Out:
# {'Name': 'KRishnaRawal', 'height': 1.9}

# %%
del my_data['Name']

# %%
my_data
# Out:
# {'height': 1.9}

# %%
my_data.clear()
my_data
# Out:
# {}
