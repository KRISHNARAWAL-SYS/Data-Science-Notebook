# %% [markdown]
# ## Module

# %% [markdown]
# ###### In python, modules are files that contain python code
# ###### and module can have classes functions and variable

# %%
import

# %% [markdown]
# ### OS Module

# %%
import os

# %%
os.getcwd()
# this path of jupiter notebook where it is been located
# Out:
# 'C:\\Users\\krishna rawal\\Python for data science script\\Mycourse'

# %%
# list all directory
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '2.ipynb',
#  '3(conditional statements).ipynb',
#  '4_Functions.ipynb',
#  '5_Module.ipynb',
#  'Example.ipynb',
#  'New Folder']

# %%
# create new directory
os.makedirs("New Folder")
